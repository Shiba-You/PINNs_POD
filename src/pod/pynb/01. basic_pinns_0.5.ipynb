# %%
import sys
sys.path.append("../../utils")
import warnings
warnings.simplefilter('ignore')


from pinns import PhysicsInformedNN
from make_data import make_data
from send_line import send_line
from make_results import make_results


import numpy as np
import tensorflow as tf
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6a1327cc1c4c> in <module>
#       5
#       6
# ----> 7 from pinns import PhysicsInformedNN
#       8 from make_data import make_data
#       9 from send_line import send_line
#
# ModuleNotFoundError: No module named 'pinns'

# %%
# %autoreload

# %%
'''
mode_th : 各モード諸条件の上位何%を教師データ候補群とするのか
'''

# pro = "asymmetric_squares"
pro = "circle"
path = "../../../data/{}/".format(pro)

layers = [3, 20, 20, 20, 20, 20, 20, 20, 20, 2]
Itration = 2*10**5
rs = 1234
train_rate = 0.5
N_train = .01 * train_rate

n_modes = 0
subject = "UU"
mode_th = .05


snap = [10]
debug = True
np.random.seed(rs)
tf.set_random_seed(rs)

# %%
X_star, x_train, y_train, t_train, u_train, v_train, TT, UU, VV, PP = make_data(path=path, N_train=N_train, n_modes=n_modes, subject=subject, mode_th=mode_th)
# Out:
# x_train :  (4950, 1)
# y_train :  (4950, 1)
# t_train :  (4950, 1)
# u_train :  (4950, 1)
# v_train :  (4950, 1)

# %%
t1 = time.time()
model = PhysicsInformedNN(x_train, y_train, t_train, u_train, v_train, layers, debug)
model.train(Itration)
t2 = time.time()
elps = (t2 - t1) / 60.
print("elps:", elps)
send_line('解析終了')
# Out:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 0.388134
#   Number of iterations: 24826
#   Number of functions evaluations: 26635
# elps: 546.0469671368598

# %%
make_results(pro, subject, train_rate, model, X_star, TT, snap, UU, VV, PP, n_modes, mode_th, N_train, Itration, elps, rs)
# Out:
# final loss values;
# 2.6613895893096924
# 1.4654045104980469
# 1.1959850788116455
